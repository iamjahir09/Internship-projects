# %%
import kagglehub

path = kagglehub.dataset_download("landrykezebou/vcor-vehicle-color-recognition-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\pc\.cache\kagglehub\datasets\landrykezebou\vcor-vehicle-color-recognition-dataset\1.archive...
# 100%|██████████| 574M/574M [03:31<00:00, 2.85MB/s]
# Extracting files...
# Path to dataset files: C:\Users\pc\.cache\kagglehub\datasets\landrykezebou\vcor-vehicle-color-recognition-dataset\versions\1
